# %%
import pandas as pd
import numpy as np

# %%
from pycaret.regression import *

# %%
import mlflow

# %%
data = pd.read_csv("raw.csv")
data.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000')

# %%
s = setup(data, 
          target='Rent', 
          session_id=123, 
          experiment_name='modelo_base', 
          log_experiment=True)
# Out:
# <style type="text/css">
# #T_d6692_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d6692">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6692_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d6692_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6692_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6692_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d6692_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d6692_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6692_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d6692_row1_col1" class="data row1 col1" >Rent</td>
#     </tr>
#     <tr>
#       <th id="T_d6692_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_ccfb5 th {
#   text-align: left;
# }
# ...

# %%
model1 = create_model('rf')

# %%
tune = tune_model(best, n_iter = 100)
# Out:
# <style type="text/css">
# #T_a5d4f_row10_col0, #T_a5d4f_row10_col1, #T_a5d4f_row10_col2, #T_a5d4f_row10_col3, #T_a5d4f_row10_col4, #T_a5d4f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a5d4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5d4f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a5d4f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a5d4f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a5d4f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a5d4f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a5d4f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
final = finalize_model(tune)

# %%
get_logs()
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_logs()
#
# File d:\trabajo\venv\lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File d:\trabajo\venv\lib\site-packages\pycaret\regression\functional.py:2475, in get_logs(experiment_name, save)
#    2445 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    2446 def get_logs(experiment_name: Optional[str] = None, save: bool = False) -> pd.DataFrame:
#    2447     """
#    2448     Returns a table of experiment logs. Only works when ``log_experiment``
#    2449     is True when initializing the ``setup`` function.
#    (...)
#    2472
#    2473     """
# ...
